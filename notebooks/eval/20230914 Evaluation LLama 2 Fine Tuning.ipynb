# %%
import os
import datetime
import random

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

# %%
df_transcripts = pd.read_csv('../../data/transcripts_health_2021.csv')
df_transcripts
# Out:
#                                        call_transcript     mood  agent_number  \
# 0    Agent 3: Thank you for calling HealthHarbor, m...  neutral             3
# 1    Agent 2: Thank you for calling HealthHarbor, m...  neutral             2
# 2    Agent 4: Thank you for calling HealthHarbor, m...    angry             4
# 3    Agent 1: Thank you for calling HealthHarbor, m...   scared             1
# 4    [Phone ringing]\n\nAgent 3: Thank you for call...  neutral             3
# ..                                                 ...      ...           ...
# 995  Agent 3: Thank you for calling HealthHarbor, m...  worried             3
# 996  Agent 3: Thank you for calling HealthHarbor, m...  neutral             3
# 997  Agent 4: Thank you for calling HealthHarbor, m...  neutral             4
# 998  [Phone ringing]\n\nAgent 2: Thank you for call...  worried             2
# 999  Agent 4: Thank you for calling HealthHarbor. M...  neutral             4
#
# ...

# %%
df_predict  = pd.read_csv('../../data/interim/llama2_finetuning_prediction_hc_1000rows_20230915060442.csv')
df_predict
# Out:
#                                        call_transcript  \
# 0    Agent 3: Thank you for calling HealthHarbor, m...
# 1    Agent 2: Thank you for calling HealthHarbor, m...
# 2    Agent 4: Thank you for calling HealthHarbor, m...
# 3    Agent 1: Thank you for calling HealthHarbor, m...
# 4    [Phone ringing]\n\nAgent 3: Thank you for call...
# ..                                                 ...
# 995  Agent 3: Thank you for calling HealthHarbor, m...
# 996  Agent 3: Thank you for calling HealthHarbor, m...
# 997  Agent 4: Thank you for calling HealthHarbor, m...
# 998  [Phone ringing]\n\nAgent 2: Thank you for call...
# 999  Agent 4: Thank you for calling HealthHarbor. M...
#
#                                          intention  \
# 0             Medical Advice or Symptom Assessment
# 1                                General Inquiries
# 2                             Lab and Test Results
# 3              Follow-up Calls and Care Management
# ...

# %%
# create two list of intention one fro the prediction and one for the real intention
# then compare them and see the accuracy
l_intention_predict = df_transcripts['intention'].tolist()
l_intention_real = df_predict['Prediction'].tolist()

# %% [markdown]
# # Evaluation Metrics

# %% [markdown]
# ## Accuracy, Precision, Recall and F1

# %%
accuracy = accuracy_score(l_intention_real, l_intention_predict)
precision_score = precision_score(l_intention_real, l_intention_predict, average='weighted')
recall_score = recall_score(l_intention_real, l_intention_predict, average='weighted')
f1_score = f1_score(l_intention_real, l_intention_predict, average='weighted')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision_score:.2f}")
print(f"Recall: {recall_score:.2f}")
print(f"F1: {f1_score:.2f}")
# Out:
# Accuracy: 0.91
# Precision: 0.84
# Recall: 0.91
# F1: 0.87
# /Users/urvog/miniconda3/envs/envIEDR/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
