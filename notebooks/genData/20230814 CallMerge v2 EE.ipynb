# %%
import pandas as pd
import numpy as np
import os

# %%
#importing data

#list of all the files from ../../data
files = os.listdir("../../data/raw2/")

#iterating through the files and appending them to a dataframe
df = pd.DataFrame()
for file in files:
    if file.endswith(".csv"):
        #concatenating the dataframes
        df = pd.concat([df, pd.read_csv("../../data/raw2/"+file)])

# %%
df
# Out:
#                                       call_transcript     mood  agent_number  \
# 0   Agent 1: Good morning, thank you for calling E...    angry             1
# 1   Agent 2: Thank you for calling ElectricVolt, m...    happy             2
# 2   Agent 3: Thank you for calling ElectricVolt, m...    happy             3
# 3   Agent 2: Thank you for calling ElectricVolt, m...    happy             2
# 4   Agent 1: Thank you for calling ElectricVolt, m...    angry             1
# ..                                                ...      ...           ...
# 45  Agent 2: Good morning, thank you for calling E...    angry             2
# 46  Agent 2: Thank you for calling ElectricVolt. M...  neutral             2
# 47  Agent 3: Thank you for calling ElectricVolt. M...  neutral             3
# 48  [Phone rings]\n\nAgent 3: Thank you for callin...  neutral             3
# 49  Call Center Agent: Thank you for calling Elect...    happy             2
#
#                                 intention  resolution
# 0                Feedback and Suggestions    resolved
# 1   Technical Support and Troubleshooting    resolved
# 2                      Account Management    resolved
# 3                 Outages and Emergencies    resolved
# 4                    Billing and Payments    resolved
# ..                                    ...         ...
# 45              Complaints and Grievances    resolved
# 46               Feedback and Suggestions    resolved
# 47      Inquiries and General Information    resolved
# 48      Service Requests and Appointments  unresolved
# 49  Technical Support and Troubleshooting  unresolved
#
# [1000 rows x 5 columns]

# %%
#generating a list of 240 rows of random dates for year 2022
dates = pd.date_range(start='2022-01-01', end='2022-12-31', periods=df.shape[0])

#adding a column of random dates to the dataframe
df['Date'] = dates
df
# Out:
#                                       call_transcript     mood  agent_number  \
# 0   Agent 1: Good morning, thank you for calling E...    angry             1
# 1   Agent 2: Thank you for calling ElectricVolt, m...    happy             2
# 2   Agent 3: Thank you for calling ElectricVolt, m...    happy             3
# 3   Agent 2: Thank you for calling ElectricVolt, m...    happy             2
# 4   Agent 1: Thank you for calling ElectricVolt, m...    angry             1
# ..                                                ...      ...           ...
# 45  Agent 2: Good morning, thank you for calling E...    angry             2
# 46  Agent 2: Thank you for calling ElectricVolt. M...  neutral             2
# 47  Agent 3: Thank you for calling ElectricVolt. M...  neutral             3
# 48  [Phone rings]\n\nAgent 3: Thank you for callin...  neutral             3
# 49  Call Center Agent: Thank you for calling Elect...    happy             2
#
#                                 intention  resolution  \
# 0                Feedback and Suggestions    resolved
# 1   Technical Support and Troubleshooting    resolved
# 2                      Account Management    resolved
# 3                 Outages and Emergencies    resolved
# 4                    Billing and Payments    resolved
# ..                                    ...         ...
# 45              Complaints and Grievances    resolved
# 46               Feedback and Suggestions    resolved
# 47      Inquiries and General Information    resolved
# 48      Service Requests and Appointments  unresolved
# 49  Technical Support and Troubleshooting  unresolved
#
#                             Date
# 0  2022-01-01 00:00:00.000000000
# 1  2022-01-01 08:44:41.081081081
# 2  2022-01-01 17:29:22.162162162
# 3  2022-01-02 02:14:03.243243243
# 4  2022-01-02 10:58:44.324324324
# ..                           ...
# 45 2022-12-29 13:01:15.675675676
# 46 2022-12-29 21:45:56.756756756
# 47 2022-12-30 06:30:37.837837840
# 48 2022-12-30 15:15:18.918918920
# 49 2022-12-31 00:00:00.000000000
#
# [1000 rows x 6 columns]

# %%
#saving data
df.to_csv("../../data/transcripts_2022_v2.csv", index=False)
