# %%
import pandas as pd
import numpy as np
from langchain import PromptTemplate    
from langchain.prompts import ChatPromptTemplate
from langchain.chat_models import ChatOpenAI
import openai
import datetime
import random


import os
os.environ["OPENAI_API_KEY"] = "XXXXXX"
openai.api_key = os.getenv("OPENAI_API_KEY")
OPENAI_MODEL_16K = "gpt-3.5-turbo-16k"
OPENAI_MODEL_4K = "gpt-3.5-turbo"

# %% [markdown]
# # Initializing LLM Model

# %%
chat_model = ChatOpenAI(model_name = OPENAI_MODEL_4K, temperature=0.7)

# %% [markdown]
# # Defining Prompt Templates

# %% [markdown]
# # Importing Script and Intention Calls

# %%
df_intention = pd.read_excel('../../data/intention_calls_health.xlsx', sheet_name='intention1')
df_intention
# Out:
#    ID                      Intention Call Categories  \
# 0   1                         Appointment Scheduling
# 1   2           Medical Advice or Symptom Assessment
# 2   3  Medication Refills and Prescription Inquiries
# 3   4                Insurance and Billing Inquiries
# 4   5                           Lab and Test Results
# 5   6          Referrals and Specialist Appointments
# 6   7                Healthcare Facility Information
# 7   8                       Medical Records Requests
# 8   9            Follow-up Calls and Care Management
# 9  10                              General Inquiries
#
#                            Definition or Description
# 0  Patients call to schedule, reschedule, or canc...
# 1  Patients seek guidance on managing symptoms, m...
# 2  Patients request refills for their medications...
# 3  Patients may have questions about their insura...
# 4  Patients call to inquire about their test resu...
# 5  Patients may require assistance in getting ref...
# 6  Patients seek information about healthcare fac...
# 7  Patients may inquire about obtaining copies of...
# 8  Healthcare providers may follow up with patien...
# 9  Patients might call with general questions abo...

# %% [markdown]
# ## Parameters for the company

# %% [markdown]
# ## Template 1.1

# %%
prompt_call_template1 = ChatPromptTemplate.from_template(
    """
    The hospital is a healthcare facility that offers a wide range of medical services to patients in need of care.

    The name of the hospital is {company_name}.

    Generate a transcript of a call between two people for a call center in a healthcare company.

    The conversation will be between a customer and a call center agent.

    Generate a random name and last name and for the customer and for the agent will be agent {agent_number}.

    The customer mood will be: {customer_mood}.

    The conversation should be between 5 and 10 minutes long with this intention or reason call: {intention}.

    The conversation is {type_resolution}.
    
    """
)

# %%
calls_list = []
calls_metadata = []
#generate a list of mood for the customer
mood_list = ["worried", "neutral", "angry","neutral","neutral","scared","worried"] #Two times to increase the probability of happy and neutral

intention_list = df_intention['Intention Call Categories']
range_calls = 200
n_agent = 4
#generate a list of type of resolution
resolution_list = ["resolved", "resolved", "resolved", "unresolved"] #two time resolved to increase the probability of resolved

for i in range(range_calls):
    #generaintg random agent number from 1 
    agent_number = random.randint(1,n_agent)

    #generate a random mood from the mood list
    mood = random.choice(mood_list)
    intention = random.choice(intention_list)
    resolution = random.choice(resolution_list)

    call5 = prompt_call_template1.format_messages(company_name="HealthHarbor", 
                                                  customer_mood=mood, 
                                                  agent_number=agent_number,
                                                  intention=intention,
                                                  type_resolution=resolution)
    
    print("Generating Call Transcript #", i)
    response = chat_model(call5)
    calls_list.append(response.content)

    #append mood and agent number to the metadata
    calls_metadata.append([mood, agent_number, intention,resolution])

df_metadata = pd.DataFrame(calls_metadata)
df_calls = pd.DataFrame(calls_list)

df_calls = pd.concat([df_calls, df_metadata], axis=1)
df_calls.columns = ['call_transcript', 'mood', 'agent_number', 'intention', 'resolution']

now = datetime.datetime.now()

#change now to string with format YYYYMMDDhhmmss
now = now.strftime("%Y%m%d%H%M%S")
df_calls.to_csv('../../data/raw3_health/calls'+now+'.csv', index=False)
# Out:
# Generating Call Transcript # 0
# Generating Call Transcript # 1
# Generating Call Transcript # 2
# Generating Call Transcript # 3
# Generating Call Transcript # 4
# Generating Call Transcript # 5
# Generating Call Transcript # 6
# Generating Call Transcript # 7
# Generating Call Transcript # 8
# Generating Call Transcript # 9
# Generating Call Transcript # 10
# Generating Call Transcript # 11
# Generating Call Transcript # 12
# Generating Call Transcript # 13
# Generating Call Transcript # 14
# Generating Call Transcript # 15
# Generating Call Transcript # 16
# Generating Call Transcript # 17
# Generating Call Transcript # 18
# Generating Call Transcript # 19
# Generating Call Transcript # 20
# Generating Call Transcript # 21
# Generating Call Transcript # 22
# Generating Call Transcript # 23
# Generating Call Transcript # 24
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600).
# Generating Call Transcript # 25
# Generating Call Transcript # 26
# Generating Call Transcript # 27
# Generating Call Transcript # 28
# Generating Call Transcript # 29
# Generating Call Transcript # 30
# Generating Call Transcript # 31
# Generating Call Transcript # 32
# Generating Call Transcript # 33
# Generating Call Transcript # 34
# Generating Call Transcript # 35
# Generating Call Transcript # 36
# Generating Call Transcript # 37
# Generating Call Transcript # 38
# Generating Call Transcript # 39
# Generating Call Transcript # 40
# Generating Call Transcript # 41
# Generating Call Transcript # 42
# Generating Call Transcript # 43
# Generating Call Transcript # 44
# Generating Call Transcript # 45
# Generating Call Transcript # 46
# Generating Call Transcript # 47
# Generating Call Transcript # 48
# Generating Call Transcript # 49
# Generating Call Transcript # 50
# Generating Call Transcript # 51
# Generating Call Transcript # 52
# Generating Call Transcript # 53
# Generating Call Transcript # 54
# Generating Call Transcript # 55
# Generating Call Transcript # 56
# Generating Call Transcript # 57
# Generating Call Transcript # 58
# Generating Call Transcript # 59
# Generating Call Transcript # 60
# Generating Call Transcript # 61
# Generating Call Transcript # 62
# Generating Call Transcript # 63
# Generating Call Transcript # 64
# Generating Call Transcript # 65
# Generating Call Transcript # 66
# Generating Call Transcript # 67
# Generating Call Transcript # 68
# Generating Call Transcript # 69
# Generating Call Transcript # 70
# Generating Call Transcript # 71
# Generating Call Transcript # 72
# Generating Call Transcript # 73
# Generating Call Transcript # 74
# Generating Call Transcript # 75
# Generating Call Transcript # 76
# Generating Call Transcript # 77
# Generating Call Transcript # 78
# Generating Call Transcript # 79
# Generating Call Transcript # 80
# Generating Call Transcript # 81
# Generating Call Transcript # 82
# Generating Call Transcript # 83
# Generating Call Transcript # 84
# Generating Call Transcript # 85
# Generating Call Transcript # 86
# Generating Call Transcript # 87
# Generating Call Transcript # 88
# Generating Call Transcript # 89
# Generating Call Transcript # 90
# Generating Call Transcript # 91
# Generating Call Transcript # 92
# Generating Call Transcript # 93
# Generating Call Transcript # 94
# Generating Call Transcript # 95
# Generating Call Transcript # 96
# Generating Call Transcript # 97
# Generating Call Transcript # 98
# Generating Call Transcript # 99
# Generating Call Transcript # 100
# Generating Call Transcript # 101
# Generating Call Transcript # 102
# Generating Call Transcript # 103
# Generating Call Transcript # 104
# Generating Call Transcript # 105
# Generating Call Transcript # 106
# Generating Call Transcript # 107
# Generating Call Transcript # 108
# Generating Call Transcript # 109
# Generating Call Transcript # 110
# Generating Call Transcript # 111
# Generating Call Transcript # 112
# Generating Call Transcript # 113
# Generating Call Transcript # 114
# Generating Call Transcript # 115
# Generating Call Transcript # 116
# Generating Call Transcript # 117
# Generating Call Transcript # 118
# Generating Call Transcript # 119
# Generating Call Transcript # 120
# Generating Call Transcript # 121
# Generating Call Transcript # 122
# Generating Call Transcript # 123
# Generating Call Transcript # 124
# Generating Call Transcript # 125
# Generating Call Transcript # 126
# Generating Call Transcript # 127
# Generating Call Transcript # 128
# Generating Call Transcript # 129
# Generating Call Transcript # 130
# Generating Call Transcript # 131
# Generating Call Transcript # 132
# Generating Call Transcript # 133
# Generating Call Transcript # 134
# Generating Call Transcript # 135
# Generating Call Transcript # 136
# Generating Call Transcript # 137
# Generating Call Transcript # 138
# Generating Call Transcript # 139
# Generating Call Transcript # 140
# Generating Call Transcript # 141
# Generating Call Transcript # 142
# Generating Call Transcript # 143
# Generating Call Transcript # 144
# Generating Call Transcript # 145
# Generating Call Transcript # 146
# Generating Call Transcript # 147
# Generating Call Transcript # 148
# Generating Call Transcript # 149
# Generating Call Transcript # 150
# Generating Call Transcript # 151
# Generating Call Transcript # 152
# Generating Call Transcript # 153
# Generating Call Transcript # 154
# Generating Call Transcript # 155
# Generating Call Transcript # 156
# Generating Call Transcript # 157
# Generating Call Transcript # 158
# Generating Call Transcript # 159
# Generating Call Transcript # 160
# Generating Call Transcript # 161
# Generating Call Transcript # 162
# Generating Call Transcript # 163
# Generating Call Transcript # 164
# Generating Call Transcript # 165
# Generating Call Transcript # 166
# Generating Call Transcript # 167
# Generating Call Transcript # 168
# Generating Call Transcript # 169
# Generating Call Transcript # 170
# Generating Call Transcript # 171
# Generating Call Transcript # 172
# Generating Call Transcript # 173
# Generating Call Transcript # 174
# Generating Call Transcript # 175
# Generating Call Transcript # 176
# Generating Call Transcript # 177
# Generating Call Transcript # 178
# Generating Call Transcript # 179
# Generating Call Transcript # 180
# Generating Call Transcript # 181
# Generating Call Transcript # 182
# Generating Call Transcript # 183
# Generating Call Transcript # 184
# Generating Call Transcript # 185
# Generating Call Transcript # 186
# Generating Call Transcript # 187
# Generating Call Transcript # 188
# Generating Call Transcript # 189
# Generating Call Transcript # 190
# Generating Call Transcript # 191
# Generating Call Transcript # 192
# Generating Call Transcript # 193
# Generating Call Transcript # 194
# Generating Call Transcript # 195
# Generating Call Transcript # 196
# Generating Call Transcript # 197
# Generating Call Transcript # 198
# Generating Call Transcript # 199

# %%
df_calls
# Out:
#                                        call_transcript     mood  agent_number  \
# 0    [Phone rings]\n\nAgent 2: Thank you for callin...  neutral             2
# 1    Agent 2: Thank you for calling HealthHarbor, m...  worried             2
# 2    Agent 4: Thank you for calling HealthHarbor. M...  neutral             4
# 3    Agent 2: Thank you for calling HealthHarbor. M...  neutral             2
# 4    Agent 4: Thank you for calling HealthHarbor. M...   scared             4
# ..                                                 ...      ...           ...
# 195  Agent 2: Thank you for calling HealthHarbor. M...  worried             2
# 196  [Phone rings]\n\nAgent 3: Thank you for callin...  neutral             3
# 197  Agent 2: Thank you for calling HealthHarbor. M...  neutral             2
# 198  Agent 1: Thank you for calling HealthHarbor, m...  neutral             1
# 199  Agent 3: Thank you for calling HealthHarbor. M...  neutral             3
#
#                                  intention  resolution
# 0                        General Inquiries    resolved
# 1    Referrals and Specialist Appointments  unresolved
# 2          Healthcare Facility Information    resolved
# 3    Referrals and Specialist Appointments    resolved
# 4    Referrals and Specialist Appointments    resolved
# ..                                     ...         ...
# 195               Medical Records Requests    resolved
# 196        Healthcare Facility Information    resolved
# 197        Insurance and Billing Inquiries    resolved
# 198                      General Inquiries    resolved
# 199   Medical Advice or Symptom Assessment    resolved
#
# [200 rows x 5 columns]
