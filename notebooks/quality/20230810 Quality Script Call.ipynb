# %%
import pandas as pd
import numpy as np
from langchain import PromptTemplate    
from langchain.prompts import ChatPromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.output_parsers import ResponseSchema
from langchain.output_parsers import StructuredOutputParser

import openai
import tiktoken

import os
import datetime
import random

os.environ["OPENAI_API_KEY"] = "XXXXXX"
openai.api_key = os.getenv("OPENAI_API_KEY")
#OPENAI_MODEL = "gpt-3.5-turbo-16k-0613"
OPENAI_MODEL = "gpt-3.5-turbo"

# %% [markdown]
# # General Functions

# %%
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %% [markdown]
# # Importing Script Templates

# %%
df_script = pd.read_excel('../../data/scripts_call_center_ee.xlsx', sheet_name='general_script1')
df_script
# Out:
#                       Step                                       Agent Script  \
# 0                 Greeting  "Good [morning/afternoon/evening], thank you f...
# 1           Identify Issue  "Could you please tell me about the issue you'...
# 2  Confirm Account Details  "May I have your name and account number to pu...
# 3          Verify Identity  "For security, can you confirm your billing ad...
# 4            Analyze Issue  "Thank you for that information. Let me review...
# 5         Provide Solution  "I've looked into your issue, and it appears t...
# 6      Schedule Technician  "Would you like me to schedule a technician to...
# 7       Confirm Resolution  "I have scheduled the technician for [date/tim...
# 8                  Closing  "Thank you for calling [Company Name]. Have a ...
#
#                          Customer Response Options
# 0                                                -
# 1                               "[Describe issue]"
# 2              "[Provide name and account number]"
# 3             "[Provide verification information]"
# 4                                                -
# 5                                         "Yes/No"
# 6                        "[Provide date and time]"
# 7  "No, thank you" / "Yes, [describe other issue]"
# 8                             "Thank you, goodbye"

# %%
df_script['Step']
# Out:
# 0                   Greeting
# 1             Identify Issue
# 2    Confirm Account Details
# 3            Verify Identity
# 4              Analyze Issue
# 5           Provide Solution
# 6        Schedule Technician
# 7         Confirm Resolution
# 8                    Closing
# Name: Step, dtype: object

# %% [markdown]
# # Importing Data Transcripts Calls

# %%
df_transcripts = pd.read_csv('../../data/transcripts_2022.csv')
df_transcripts
# Out:
#                                             Transcript  \
# 0    Agent 1: Thank you for calling ElectricVolt. T...
# 1    Agent 2: Thank you for calling ElectricVolt, m...
# 2    Agent 2: Thank you for calling ElectricVolt. M...
# 3    Agent 3: Thank you for calling ElectricVolt, m...
# 4    Agent 1: Thank you for calling ElectricVolt, m...
# ..                                                 ...
# 235  Agent 1: Thank you for calling ElectricVolt, m...
# 236  Agent 1: Thank you for calling ElectricVolt. M...
# 237  [Phone ringing]\n\nAgent 1: Thank you for call...
# 238  Agent 1: Thank you for calling ElectricVolt. M...
# 239  Agent 1: Thank you for calling ElectricVolt. M...
#
#                               Date
# 0    2022-01-01 00:00:00.000000000
# 1    2022-01-02 12:33:08.284518828
# 2    2022-01-04 01:06:16.569037656
# 3    2022-01-05 13:39:24.853556485
# 4    2022-01-07 02:12:33.138075313
# ..                             ...
# 235  2022-12-24 21:47:26.861924688
# 236  2022-12-26 10:20:35.146443516
# 237  2022-12-27 22:53:43.430962344
# 238  2022-12-29 11:26:51.715481172
# 239  2022-12-31 00:00:00.000000000
#
# [240 rows x 2 columns]

# %% [markdown]
# # Initializing Model

# %%
chat_model = ChatOpenAI(model_name = OPENAI_MODEL, temperature=0) #deterministic
chat_model
# Out:
# ChatOpenAI(cache=None, verbose=False, callbacks=None, callback_manager=None, tags=None, metadata=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo-16k-0613', temperature=0.0, model_kwargs={}, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='', request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None, tiktoken_model_name=None)

# %% [markdown]
# # Prompts Templating

# %%
prompt_template = ChatPromptTemplate.from_template(
"""
Based in the following transcript for a call center in electrical company:

{transcript}

Provide an score between 1 - 5 if following Script Quality Criteria is fulfilled:

{script_quality_criteria}

If you can't apply a criteria the check is False and the score is 0.

The ouput will be a JSON file with scores for each criteria (step) found in the transcript:

{format_instructions}

""")

# %%
#preparing schemas for output in JSON Format
QA01_Greeting_schema = ResponseSchema(name="qa01_greeting_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality of the greeting criteria, 
                             return 0 if the greeting is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             
                             """
                             % str(df_script['Agent Script'][0]))

QA02_Identify_schema = ResponseSchema(name="qa02_identify_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality  of the identification criteria, 
                             return 0 if the identification is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             """
                             % str(df_script['Agent Script'][1]))

QA03_confirm_schema = ResponseSchema(name="qa03_confirm_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality of the confirmation criteria,
                             return 0 if the confirmation is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             """
                             % str(df_script['Agent Script'][2]))      

QA04_verify_schema = ResponseSchema(name="qa04_verify_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality of the verification criteria,
                             return 0 if the verification is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             """
                             % str(df_script['Agent Script'][3]))      

QA05_analyze_schema = ResponseSchema(name="qa05_analyze_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality of the analysis criteria,
                             return 0 if the analysis is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             """
                             % str(df_script['Agent Script'][4]))                      

QA06_solution_schema = ResponseSchema(name="qa06_solution_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality of the solution criteria,
                             return 0 if the solution is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             """
                             % str(df_script['Agent Script'][5]))     

QA07_schedule_schema = ResponseSchema(name="qa07_schedule_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality of the schedule criteria,
                             return 0 if the schedule is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             """
                             % str(df_script['Agent Script'][6]))       

QA08_resolution_schema = ResponseSchema(name="qa08_resolution_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality of the resolution criteria,
                             return 0 if the resolution is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             """
                             % str(df_script['Agent Script'][7]))         

QA09_closing_schema = ResponseSchema(name="qa09_closing_schema",
                             description="""
                             Return an score from 1 to 5 based in the quality of the closing criteria,
                             return 0 if the closing is not correct or not exist

                             The Score will be based in the following Agent Script: %s
                             """
                             % str(df_script['Agent Script'][8]))          

response_schemas = [QA01_Greeting_schema, QA02_Identify_schema, QA03_confirm_schema, 
                    QA04_verify_schema, QA05_analyze_schema, QA06_solution_schema, 
                    QA07_schedule_schema, QA08_resolution_schema, QA09_closing_schema]
output_parser = StructuredOutputParser.from_response_schemas(response_schemas)
format_instructions = output_parser.get_format_instructions()

# %%
output_score_list = []
transcript_number = 1
tokens_list = []
for transcript in df_transcripts['Transcript']:
    prompt_call = prompt_template.format_messages(transcript=transcript, 
                                              script_quality_criteria=df_script,
                                              format_instructions=format_instructions)
    #Calling LLM
    print("Transcript number: ", transcript_number)

    n_tokens = num_tokens_from_string(str(prompt_call[0]),encoding_name="cl100k_base")
    print("Number of Tokens: ", n_tokens)
    response = chat_model(prompt_call)

    #Parsing LLM output
    output_dict = output_parser.parse(response.content)

    #appending intention and explanation to list
    aux_list = [output_dict.get("qa01_greeting_schema"), output_dict.get("qa02_identify_schema"), output_dict.get("qa03_confirm_schema"),
                output_dict.get("qa04_verify_schema"), output_dict.get("qa05_analyze_schema"), output_dict.get("qa06_solution_schema"),
                output_dict.get("qa07_schedule_schema"), output_dict.get("qa08_resolution_schema"), output_dict.get("qa09_closing_schema")]

    output_score_list.append(aux_list)
    tokens_list.append(n_tokens)

    transcript_number += 1
# Out:
# Transcript number:  1
# Number of Tokens:  1767
# Transcript number:  2
# Number of Tokens:  1764
# Transcript number:  3
# Number of Tokens:  1813
# Transcript number:  4
# Number of Tokens:  1857
# Transcript number:  5
# Number of Tokens:  2044
# Transcript number:  6
# Number of Tokens:  1719
# Transcript number:  7
# Number of Tokens:  1863
# Transcript number:  8
# Number of Tokens:  1704
# Transcript number:  9
# Number of Tokens:  1796
# Transcript number:  10
# Number of Tokens:  1800
# Transcript number:  11
# Number of Tokens:  1832
# Transcript number:  12
# Number of Tokens:  1754
# Transcript number:  13
# Number of Tokens:  1705
# Transcript number:  14
# Number of Tokens:  1880
# Transcript number:  15
# Number of Tokens:  1807
# Transcript number:  16
# Number of Tokens:  1699
# Transcript number:  17
# Number of Tokens:  1902
# Transcript number:  18
# Number of Tokens:  1851
# Transcript number:  19
# Number of Tokens:  1879
# Transcript number:  20
# Number of Tokens:  1889
# Transcript number:  21
# Number of Tokens:  1923
# Transcript number:  22
# Number of Tokens:  1846
# Transcript number:  23
# Number of Tokens:  1851
# Transcript number:  24
# Number of Tokens:  1771
# Transcript number:  25
# Number of Tokens:  1864
# Transcript number:  26
# Number of Tokens:  2050
# Transcript number:  27
# Number of Tokens:  1874
# Transcript number:  28
# Number of Tokens:  1767
# Transcript number:  29
# Number of Tokens:  1850
# Transcript number:  30
# Number of Tokens:  1866
# Transcript number:  31
# Number of Tokens:  1836
# Transcript number:  32
# Number of Tokens:  1824
# Transcript number:  33
# Number of Tokens:  1802
# Transcript number:  34
# Number of Tokens:  1916
# Transcript number:  35
# Number of Tokens:  1703
# Transcript number:  36
# Number of Tokens:  1766
# Transcript number:  37
# Number of Tokens:  1803
# Transcript number:  38
# Number of Tokens:  1870
# Transcript number:  39
# Number of Tokens:  1892
# Transcript number:  40
# Number of Tokens:  2085
# Transcript number:  41
# Number of Tokens:  2043
# Transcript number:  42
# Number of Tokens:  1930
# Transcript number:  43
# Number of Tokens:  1735
# Transcript number:  44
# Number of Tokens:  2031
# Transcript number:  45
# Number of Tokens:  1990
# Transcript number:  46
# Number of Tokens:  1851
# Transcript number:  47
# Number of Tokens:  2007
# Transcript number:  48
# Number of Tokens:  1758
# Transcript number:  49
# Number of Tokens:  1730
# Transcript number:  50
# Number of Tokens:  1990
# Transcript number:  51
# Number of Tokens:  2600
# Transcript number:  52
# Number of Tokens:  2103
# Transcript number:  53
# Number of Tokens:  1824
# Transcript number:  54
# Number of Tokens:  1834
# Transcript number:  55
# Number of Tokens:  2005
# Transcript number:  56
# Number of Tokens:  1968
# Transcript number:  57
# Number of Tokens:  1984
# Transcript number:  58
# Number of Tokens:  1932
# Transcript number:  59
# Number of Tokens:  1730
# Transcript number:  60
# Number of Tokens:  1716
# Transcript number:  61
# Number of Tokens:  1767
# Transcript number:  62
# Number of Tokens:  1913
# Transcript number:  63
# Number of Tokens:  1845
# Transcript number:  64
# Number of Tokens:  1753
# Transcript number:  65
# Number of Tokens:  1778
# Transcript number:  66
# Number of Tokens:  1817
# Transcript number:  67
# Number of Tokens:  1940
# Transcript number:  68
# Number of Tokens:  1819
# Transcript number:  69
# Number of Tokens:  1891
# Transcript number:  70
# Number of Tokens:  1841
# Transcript number:  71
# Number of Tokens:  1724
# Transcript number:  72
# Number of Tokens:  1766
# Transcript number:  73
# Number of Tokens:  1669
# Transcript number:  74
# Number of Tokens:  1892
# Transcript number:  75
# Number of Tokens:  1706
# Transcript number:  76
# Number of Tokens:  1778
# Transcript number:  77
# Number of Tokens:  1776
# Transcript number:  78
# Number of Tokens:  1731
# Transcript number:  79
# Number of Tokens:  1753
# Transcript number:  80
# Number of Tokens:  1782
# Transcript number:  81
# Number of Tokens:  1731
# Transcript number:  82
# Number of Tokens:  1903
# Transcript number:  83
# Number of Tokens:  1759
# Transcript number:  84
# Number of Tokens:  1748
# Transcript number:  85
# Number of Tokens:  1670
# Transcript number:  86
# Number of Tokens:  1651
# Transcript number:  87
# Number of Tokens:  1819
# Transcript number:  88
# Number of Tokens:  1811
# Transcript number:  89
# Number of Tokens:  1818
# Transcript number:  90
# Number of Tokens:  1679
# Transcript number:  91
# Number of Tokens:  1906
# Transcript number:  92
# Number of Tokens:  1742
# Transcript number:  93
# Number of Tokens:  1985
# Transcript number:  94
# Number of Tokens:  1817
# Transcript number:  95
# Number of Tokens:  1820
# Transcript number:  96
# Number of Tokens:  1783
# Transcript number:  97
# Number of Tokens:  1825
# Transcript number:  98
# Number of Tokens:  1939
# Transcript number:  99
# Number of Tokens:  1755
# Transcript number:  100
# Number of Tokens:  1909
# Transcript number:  101
# Number of Tokens:  1713
# Transcript number:  102
# Number of Tokens:  1886
# Transcript number:  103
# Number of Tokens:  1863
# Transcript number:  104
# Number of Tokens:  1651
# Transcript number:  105
# Number of Tokens:  1828
# Transcript number:  106
# Number of Tokens:  1756
# Transcript number:  107
# Number of Tokens:  1871
# Transcript number:  108
# Number of Tokens:  1748
# Transcript number:  109
# Number of Tokens:  1914
# Transcript number:  110
# Number of Tokens:  1747
# Transcript number:  111
# Number of Tokens:  1932
# Transcript number:  112
# Number of Tokens:  1847
# Transcript number:  113
# Number of Tokens:  1955
# Transcript number:  114
# Number of Tokens:  1924
# Transcript number:  115
# Number of Tokens:  1920
# Transcript number:  116
# Number of Tokens:  1881
# Transcript number:  117
# Number of Tokens:  1853
# Transcript number:  118
# Number of Tokens:  1770
# Transcript number:  119
# Number of Tokens:  1848
# Transcript number:  120
# Number of Tokens:  1767
# Transcript number:  121
# Number of Tokens:  1804
# Transcript number:  122
# Number of Tokens:  1872
# Transcript number:  123
# Number of Tokens:  1825
# Transcript number:  124
# Number of Tokens:  1850
# Transcript number:  125
# Number of Tokens:  1832
# Transcript number:  126
# Number of Tokens:  1925
# Transcript number:  127
# Number of Tokens:  1810
# Transcript number:  128
# Number of Tokens:  1863
# Transcript number:  129
# Number of Tokens:  1907
# Transcript number:  130
# Number of Tokens:  1796
# Transcript number:  131
# Number of Tokens:  1692
# Transcript number:  132
# Number of Tokens:  1922
# Transcript number:  133
# Number of Tokens:  1906
# Transcript number:  134
# Number of Tokens:  1901
# Transcript number:  135
# Number of Tokens:  1833
# Transcript number:  136
# Number of Tokens:  1805
# Transcript number:  137
# Number of Tokens:  1901
# Transcript number:  138
# Number of Tokens:  1908
# Transcript number:  139
# Number of Tokens:  1843
# Transcript number:  140
# Number of Tokens:  1781
# Transcript number:  141
# Number of Tokens:  1763
# Transcript number:  142
# Number of Tokens:  1816
# Transcript number:  143
# Number of Tokens:  1728
# Transcript number:  144
# Number of Tokens:  1817
# Transcript number:  145
# Number of Tokens:  2081
# Transcript number:  146
# Number of Tokens:  1801
# Transcript number:  147
# Number of Tokens:  1921
# Transcript number:  148
# Number of Tokens:  1786
# Transcript number:  149
# Number of Tokens:  1949
# Transcript number:  150
# Number of Tokens:  1798
# Transcript number:  151
# Number of Tokens:  2092
# Transcript number:  152
# Number of Tokens:  1692
# Transcript number:  153
# Number of Tokens:  1778
# Transcript number:  154
# Number of Tokens:  1783
# Transcript number:  155
# Number of Tokens:  2178
# Transcript number:  156
# Number of Tokens:  2076
# Transcript number:  157
# Number of Tokens:  1764
# Transcript number:  158
# Number of Tokens:  1827
# Transcript number:  159
# Number of Tokens:  1969
# Transcript number:  160
# Number of Tokens:  1932
# Transcript number:  161
# Number of Tokens:  1743
# Transcript number:  162
# Number of Tokens:  1738
# Transcript number:  163
# Number of Tokens:  1919
# Transcript number:  164
# Number of Tokens:  1863
# Transcript number:  165
# Number of Tokens:  1679
# Transcript number:  166
# Number of Tokens:  1708
# Transcript number:  167
# Number of Tokens:  1667
# Transcript number:  168
# Number of Tokens:  1646
# Transcript number:  169
# Number of Tokens:  1727
# Transcript number:  170
# Number of Tokens:  1893
# Transcript number:  171
# Number of Tokens:  1802
# Transcript number:  172
# Number of Tokens:  1795
# Transcript number:  173
# Number of Tokens:  1743
# Transcript number:  174
# Number of Tokens:  1657
# Transcript number:  175
# Number of Tokens:  1790
# Transcript number:  176
# Number of Tokens:  1976
# Transcript number:  177
# Number of Tokens:  1739
# Transcript number:  178
# Number of Tokens:  2075
# Transcript number:  179
# Number of Tokens:  1816
# Transcript number:  180
# Number of Tokens:  1716
# Transcript number:  181
# Number of Tokens:  1810
# Transcript number:  182
# Number of Tokens:  1919
# Transcript number:  183
# Number of Tokens:  1847
# Transcript number:  184
# Number of Tokens:  2080
# Transcript number:  185
# Number of Tokens:  1706
# Transcript number:  186
# Number of Tokens:  1809
# Transcript number:  187
# Number of Tokens:  1894
# Transcript number:  188
# Number of Tokens:  1947
# Transcript number:  189
# Number of Tokens:  1803
# Transcript number:  190
# Number of Tokens:  1838
# Transcript number:  191
# Number of Tokens:  1996
# Transcript number:  192
# Number of Tokens:  1806
# Transcript number:  193
# Number of Tokens:  1801
# Transcript number:  194
# Number of Tokens:  1834
# Transcript number:  195
# Number of Tokens:  1965
# Transcript number:  196
# Number of Tokens:  1798
# Transcript number:  197
# Number of Tokens:  1957
# Transcript number:  198
# Number of Tokens:  1754
# Transcript number:  199
# Number of Tokens:  2004
# Transcript number:  200
# Number of Tokens:  1910
# Transcript number:  201
# Number of Tokens:  1908
# Transcript number:  202
# Number of Tokens:  1801
# Transcript number:  203
# Number of Tokens:  2107
# Transcript number:  204
# Number of Tokens:  1987
# Transcript number:  205
# Number of Tokens:  2053
# Transcript number:  206
# Number of Tokens:  2053
# Transcript number:  207
# Number of Tokens:  1909
# Transcript number:  208
# Number of Tokens:  1986
# Transcript number:  209
# Number of Tokens:  1863
# Transcript number:  210
# Number of Tokens:  1902
# Transcript number:  211
# Number of Tokens:  1979
# Transcript number:  212
# Number of Tokens:  1989
# Transcript number:  213
# Number of Tokens:  1970
# Transcript number:  214
# Number of Tokens:  2019
# Transcript number:  215
# Number of Tokens:  1932
# Transcript number:  216
# Number of Tokens:  1950
# Transcript number:  217
# Number of Tokens:  1924
# Transcript number:  218
# Number of Tokens:  1934
# Transcript number:  219
# Number of Tokens:  2010
# Transcript number:  220
# Number of Tokens:  1949
# Transcript number:  221
# Number of Tokens:  1763
# Transcript number:  222
# Number of Tokens:  1784
# Transcript number:  223
# Number of Tokens:  2832
# Transcript number:  224
# Number of Tokens:  1779
# Transcript number:  225
# Number of Tokens:  2112
# Transcript number:  226
# Number of Tokens:  1736
# Transcript number:  227
# Number of Tokens:  1894
# Transcript number:  228
# Number of Tokens:  1947
# Transcript number:  229
# Number of Tokens:  1785
# Transcript number:  230
# Number of Tokens:  1910
# Transcript number:  231
# Number of Tokens:  1826
# Transcript number:  232
# Number of Tokens:  1904
# Transcript number:  233
# Number of Tokens:  1932
# Transcript number:  234
# Number of Tokens:  1855
# Transcript number:  235
# Number of Tokens:  2118
# Transcript number:  236
# Number of Tokens:  1731
# Transcript number:  237
# Number of Tokens:  1876
# Transcript number:  238
# Number of Tokens:  2041
# Transcript number:  239
# Number of Tokens:  1805
# Transcript number:  240
# Number of Tokens:  1898

# %% [markdown]
# # Saving QA Transcript

# %%
df_score_transcript = pd.DataFrame(output_score_list)
df_score_transcript.columns = "QA_"+df_script['Step']

# %%
#append df_score_transcript to df_transcript as additinoal columns
df_transcripts_final_score = df_transcripts.copy()

df_transcripts_final_score = pd.concat([df_transcripts_final_score, df_score_transcript], axis=1)
df_transcripts_final_score
# Out:
#                                             Transcript  \
# 0    Agent 1: Thank you for calling ElectricVolt. T...
# 1    Agent 2: Thank you for calling ElectricVolt, m...
# 2    Agent 2: Thank you for calling ElectricVolt. M...
# 3    Agent 3: Thank you for calling ElectricVolt, m...
# 4    Agent 1: Thank you for calling ElectricVolt, m...
# ..                                                 ...
# 235  Agent 1: Thank you for calling ElectricVolt, m...
# 236  Agent 1: Thank you for calling ElectricVolt. M...
# 237  [Phone ringing]\n\nAgent 1: Thank you for call...
# 238  Agent 1: Thank you for calling ElectricVolt. M...
# 239  Agent 1: Thank you for calling ElectricVolt. M...
#
#                               Date QA_Greeting QA_Identify Issue  \
# 0    2022-01-01 00:00:00.000000000           5                 5
# 1    2022-01-02 12:33:08.284518828           5                 5
# 2    2022-01-04 01:06:16.569037656           5                 5
# 3    2022-01-05 13:39:24.853556485           5                 5
# 4    2022-01-07 02:12:33.138075313           5                 5
# ..                             ...         ...               ...
# 235  2022-12-24 21:47:26.861924688           5                 5
# 236  2022-12-26 10:20:35.146443516           5                 5
# 237  2022-12-27 22:53:43.430962344           5                 5
# 238  2022-12-29 11:26:51.715481172           5                 5
# 239  2022-12-31 00:00:00.000000000           5                 5
#
#     QA_Confirm Account Details QA_Verify Identity QA_Analyze Issue  \
# 0                            4                  4                5
# 1                            4                  4                5
# 2                            5                  4                5
# 3                            5                  5                5
# 4                            5                  5                5
# ..                         ...                ...              ...
# 235                          5                  4                5
# 236                          4                  4                5
# 237                          4                  4                5
# 238                          5                  5                5
# 239                          5                  5                5
#
#     QA_Provide Solution QA_Schedule Technician QA_Confirm Resolution  \
# 0                     5                      5                     5
# 1                     5                      5                     5
# 2                     5                      5                     5
# 3                     5                      5                     5
# 4                     5                      5                     5
# ..                  ...                    ...                   ...
# 235                   5                      5                     5
# 236                   5                      5                     5
# 237                   5                      5                     5
# 238                   5                      5                     5
# 239                   5                      5                     5
#
#     QA_Closing
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5
# ..         ...
# 235          5
# 236          5
# 237          5
# 238          5
# 239          5
#
# [240 rows x 11 columns]

# %%
now = datetime.datetime.now()
now = now.strftime("%Y%m%d%H%M%S")

df_transcripts_final_score.to_csv("../../data/interim/transcripts_final_score_{}.csv".format(now), index=False)
